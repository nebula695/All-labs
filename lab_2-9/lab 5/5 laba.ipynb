# %% [markdown]
# Код программы для отображения информации о книге:

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_info(self):
        return f"Название книги: {self.title}, Автор: {self.author}, Год издания: {self.year}"
book = Book(input("Название книги: "),input("Автор: "),input("Год издания: "))
print(book.get_info())
# Out:
# Название книги: lo
# Автор: jo
# Год издания: 1188
# Название книги: lo, Автор: jo, Год издания: 1188

# %% [markdown]
# Программа для отображения измененного радиуса круга:

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius
    def get_radius(self):
        return self.radius
    def set_radius(self, new_radius):
        self.radius = new_radius
circle = Circle(5)
print("радиус -", circle.get_radius())
circle.set_radius(10)
print("радиус -", circle.get_radius())
# Out:
# радиус - 5
# радиус - 10
